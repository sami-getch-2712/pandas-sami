# %%
import pandas as pd

# %%
df = pd.read_csv("coursera_course_dataset_v3.csv")
df
# Out:
#      Unnamed: 0                                  Title  \
# 0             0                   Google Cybersecurity
# 1             1                  Google Data Analytics
# 2             3             Google Project Management:
# 3             4                       IBM Data Science
# 4             5  Google Digital Marketing & E-commerce
# ..          ...                                    ...
# 618         624              Google Workspace Security
# 619         625   Cybersecurity for Tech Professionals
# 620         626             Cybersecurity in the Cloud
# 621         627                   Applied Cryptography
# 622         628              Python for Active Defense
#
#                       Organization  \
# 0                           Google
# 1                           Google
# 2                           Google
# 3                              IBM
# 4                           Google
# ..                             ...
# 618                   Google Cloud
# ...

# %%
#count Distnict values - Descending
df["Organization"].value_counts()
# Out:
# Organization
# IBM                                                69
# Google Cloud                                       67
# Google                                             65
# DeepLearning.AI                                    24
# University of Pennsylvania                         22
#                                                    ..
# The Museum of Modern Art                            1
# Eindhoven University of Technology                  1
# Fractal Analytics                                   1
# The University of North Carolina at Chapel Hill     1
# Campus BBVA                                         1
# Name: count, Length: 115, dtype: int64

# %%
#count Distnict values - Ascending
df["Organization"].value_counts(ascending = True)
# Out:
# Organization
# EDHEC Business School                       1
# HEC Paris                                   1
# Starweaver                                  1
# Icahn School of Medicine at Mount Sinai     1
# University of Copenhagen                    1
#                                            ..
# University of Pennsylvania                 22
# DeepLearning.AI                            24
# Google                                     65
# Google Cloud                               67
# IBM                                        69
# Name: count, Length: 115, dtype: int64

# %%
# get Organization with out NaN
# by default the value_counts() functions returns all values wich are not null
# value_counts(dropna = False) to get null values to be counted.

df["Organization"].value_counts(dropna = False)
# Out:
# Organization
# IBM                                                69
# Google Cloud                                       67
# Google                                             65
# DeepLearning.AI                                    24
# University of Pennsylvania                         22
#                                                    ..
# The Museum of Modern Art                            1
# Eindhoven University of Technology                  1
# Fractal Analytics                                   1
# The University of North Carolina at Chapel Hill     1
# Campus BBVA                                         1
# Name: count, Length: 115, dtype: int64

# %%
# get the Relative frequency - or percentage
df["Organization"].value_counts(normalize = True)
# Out:
# Organization
# IBM                                                0.110754
# Google Cloud                                       0.107544
# Google                                             0.104334
# DeepLearning.AI                                    0.038523
# University of Pennsylvania                         0.035313
#                                                      ...
# The Museum of Modern Art                           0.001605
# Eindhoven University of Technology                 0.001605
# Fractal Analytics                                  0.001605
# The University of North Carolina at Chapel Hill    0.001605
# Campus BBVA                                        0.001605
# Name: proportion, Length: 115, dtype: float64

# %%
#get specific item count : specific column
df["Organization"].value_counts()["IBM"]
# Out:
# 69

# %%
#count groupby unique values by Size : retuens in alphabetic order
df.groupby("Organization").size()
# Out:
# Organization
# Advancing Women in Tech      1
# Akamai Technologies, Inc.    2
# Alibaba Cloud Academy        1
# Amazon Web Services          7
# Arizona State University     3
#                             ..
# Vanderbilt University        5
# Wesleyan University          1
# Yale University              6
# Yonsei University            2
# École Polytechnique          1
# Length: 115, dtype: int64

# %%
#count groupby unique values by Count
df.groupby("Organization").count()
# Out:
#                            Unnamed: 0  Title  Skills  Ratings  course_url  \
# Organization
# Advancing Women in Tech             1      1       1        1           1
# Akamai Technologies, Inc.           2      2       2        2           1
# Alibaba Cloud Academy               1      1       1        1           0
# Amazon Web Services                 7      7       7        7           5
# Arizona State University            3      3       3        3           2
# ...                               ...    ...     ...      ...         ...
# Vanderbilt University               5      5       5        5           3
# Wesleyan University                 1      1       1        1           1
# Yale University                     6      6       6        6           5
# Yonsei University                   2      2       2        2           0
# École Polytechnique                 1      1       1        1           0
#
# ...

# %%
#get a count of all colums across all colums
df.apply(pd.value_counts)
# Out:
#                    Unnamed: 0  Title  Organization  Skills  Ratings  \
# 0                         1.0    NaN           NaN     NaN      NaN
# 1                         1.0    NaN           NaN     NaN      NaN
# 3                         1.0    NaN           NaN     NaN      NaN
# 4                         1.0    NaN           NaN     NaN      4.0
# 5                         1.0    NaN           NaN     NaN      1.0
# ...                       ...    ...           ...     ...      ...
# Project                   NaN    NaN           NaN     NaN      NaN
# 3 - 6 Months              NaN    NaN           NaN     NaN      NaN
# 1 - 3 Months              NaN    NaN           NaN     NaN      NaN
# 1 - 4 Weeks               NaN    NaN           NaN     NaN      NaN
# Less Than 2 Hours         NaN    NaN           NaN     NaN      NaN
#
#                    course_url  course_students_enrolled  course_description  \
# ...
