# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
#Data sets in Pandas are usually multi-dimensional tables, called DataFrames.

# Series is like a column, a DataFrame is the whole table.

# %%
my_data = randn(4,3) # rows and columns
my_rows = ["A","B","C","D"] # row head 
my_columns = ["Senuy", "Selus","Rebu"] #column head

# %%
#create DataFrame.
df = pd.DataFrame(my_data, my_rows, my_columns)

# %%
df
# Out:
#       Senuy     Selus      Rebu
# A  0.753973  0.367229  0.479601
# B  2.251842  1.333780 -0.553572
# C -0.071995 -0.539321 -1.355535
# D -0.484647 -1.054335  0.495528

# %%
#import or read csv files
my_df2 = pd.read_csv("coursera_course_dataset_v3.csv")
my_df2
# Out:
#      Unnamed: 0                                  Title  \
# 0             0                   Google Cybersecurity
# 1             1                  Google Data Analytics
# 2             3             Google Project Management:
# 3             4                       IBM Data Science
# 4             5  Google Digital Marketing & E-commerce
# ..          ...                                    ...
# 618         624              Google Workspace Security
# 619         625   Cybersecurity for Tech Professionals
# 620         626             Cybersecurity in the Cloud
# 621         627                   Applied Cryptography
# 622         628              Python for Active Defense
#
#                       Organization  \
# 0                           Google
# 1                           Google
# 2                           Google
# 3                              IBM
# 4                           Google
# ..                             ...
# 618                   Google Cloud
# ...

# %%
# pull out rows 0
my_df2.loc[0]
# Out:
# Unnamed: 0                                                                  0
# Title                                                    Google Cybersecurity
# Organization                                                           Google
# Skills                       Network Security, Python Programming, Linux, ...
# Ratings                                                                   4.8
# course_url                  https://www.coursera.org/professional-certific...
# course_students_enrolled                                              700,909
# course_description          Google Cloud Fundamentals: Core Infrastructure...
# Review Count                                                              20K
# Difficulty                                                           Beginner
# Type                                                 Professional Certificate
# Duration                                                         3 - 6 Months
# Name: 0, dtype: object

# %%
# pull out rows multiple rows ex: row 0 and 1
my_df2.loc[[0,1]]
# Out:
#    Unnamed: 0                  Title Organization  \
# 0           0   Google Cybersecurity       Google
# 1           1  Google Data Analytics       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
#
#                        Type      Duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months

# %%
# pull out rows multiple rows ex: row 0 , 3 and 5:- add as much row number you want to see
my_df2.loc[[0,3,5]]
# Out:
#    Unnamed: 0                 Title Organization  \
# 0           0  Google Cybersecurity       Google
# 3           4      IBM Data Science          IBM
# 5           6      IBM Data Analyst          IBM
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 5   Python Programming, Microsoft Excel, Data Vis...      4.6
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 3  https://www.coursera.org/professional-certific...                  239,622
# 5  https://www.coursera.org/professional-certific...                  173,574
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# ...

# %%
# pull first 5 rows
my_df2.head()
# Out:
#    Unnamed: 0                                  Title Organization  \
# 0           0                   Google Cybersecurity       Google
# 1           1                  Google Data Analytics       Google
# 2           3             Google Project Management:       Google
# 3           4                       IBM Data Science          IBM
# 4           5  Google Digital Marketing & E-commerce       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# ...

# %%
# pull certian numbers of rows: ex 9 rows
my_df2.head(9)
# Out:
#    Unnamed: 0                                  Title        Organization  \
# 0           0                   Google Cybersecurity              Google
# 1           1                  Google Data Analytics              Google
# 2           3             Google Project Management:              Google
# 3           4                       IBM Data Science                 IBM
# 4           5  Google Digital Marketing & E-commerce              Google
# 5           6                       IBM Data Analyst                 IBM
# 6           7                      Google IT Support              Google
# 7           9                       Machine Learning  Multiple educators
# 8          11                       Google UX Design              Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# ...

# %%
# pull last 5 rows
my_df2.tail()
# Out:
#      Unnamed: 0                                 Title  \
# 618         624             Google Workspace Security
# 619         625  Cybersecurity for Tech Professionals
# 620         626            Cybersecurity in the Cloud
# 621         627                  Applied Cryptography
# 622         628             Python for Active Defense
#
#                       Organization  \
# 618                   Google Cloud
# 619                    Campus BBVA
# 620        University of Minnesota
# 621  University of Colorado System
# 622                        Infosec
#
#                                                 Skills  Ratings course_url  \
# 618   Security Engineering, Security Strategy, Soft...      4.7        NaN
# 619   Computer Security Incident Management, System...      4.7        NaN
# 620   Security Engineering, System Security, Networ...      4.3        NaN
# 621   Cryptography, Security Engineering, Algorithm...      4.5        NaN
# ...

# %%
# pull certian numbers of rows: ex 6 rows from last 
my_df2.tail(6)
# Out:
#      Unnamed: 0                                 Title  \
# 617         623                   Security Principles
# 618         624             Google Workspace Security
# 619         625  Cybersecurity for Tech Professionals
# 620         626            Cybersecurity in the Cloud
# 621         627                  Applied Cryptography
# 622         628             Python for Active Defense
#
#                       Organization  \
# 617                           ISC2
# 618                   Google Cloud
# 619                    Campus BBVA
# 620        University of Minnesota
# 621  University of Colorado System
# 622                        Infosec
#
#                                                 Skills  Ratings  \
# 617                          Leadership and Management      4.7
# 618   Security Engineering, Security Strategy, Soft...      4.7
# 619   Computer Security Incident Management, System...      4.7
# 620   Security Engineering, System Security, Networ...      4.3
# ...

# %%
# grab info about dataframe
my_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                623 non-null    int64
#  1   Title                     623 non-null    object
#  2   Organization              623 non-null    object
#  3   Skills                    623 non-null    object
#  4   Ratings                   623 non-null    float64
#  5   course_url                403 non-null    object
#  6   course_students_enrolled  387 non-null    object
#  7   course_description        402 non-null    object
#  8   Review Count              623 non-null    object
#  9   Difficulty                623 non-null    object
#  10  Type                      623 non-null    object
#  11  Duration                  623 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 58.5+ KB

# %%
#grab the shape of each column
my_df2.shape
# Out:
# (623, 12)

# %%
#get dimwnssion of dataframe
my_df2.ndim
# Out:
# 2

# %%
#get column datatype
my_df2.dtypes
# Out:
# Unnamed: 0                    int64
# Title                        object
# Organization                 object
# Skills                       object
# Ratings                     float64
# course_url                   object
# course_students_enrolled     object
# course_description           object
# Review Count                 object
# Difficulty                   object
# Type                         object
# Duration                     object
# dtype: object

# %%
#get statisctics about the data
my_df2.describe()
# Out:
#        Unnamed: 0     Ratings
# count  623.000000  623.000000
# mean   316.590690    4.640931
# std    180.579572    0.195883
# min      0.000000    2.800000
# 25%    161.500000    4.600000
# 50%    317.000000    4.700000
# 75%    472.500000    4.800000
# max    628.000000    5.000000

# %%
#describe specific column
my_df2["Organization"].describe()
# Out:
# count     623
# unique    115
# top       IBM
# freq       69
# Name: Organization, dtype: object

# %%
#select specific column using brackets
# pulling out using column name this gives as pandas Series.
my_df2["Organization"]
# Out:
# 0                             Google
# 1                             Google
# 2                             Google
# 3                                IBM
# 4                             Google
#                    ...
# 618                     Google Cloud
# 619                      Campus BBVA
# 620          University of Minnesota
# 621    University of Colorado System
# 622                          Infosec
# Name: Organization, Length: 623, dtype: object

# %%
#select specific column using dot notation
# pulling out using column name this gives as pandas Series.
my_df2.Organization
# Out:
# 0                             Google
# 1                             Google
# 2                             Google
# 3                                IBM
# 4                             Google
#                    ...
# 618                     Google Cloud
# 619                      Campus BBVA
# 620          University of Minnesota
# 621    University of Colorado System
# 622                          Infosec
# Name: Organization, Length: 623, dtype: object

# %%
#select specific column using location
my_df2.iloc[:,0]
# Out:
# 0        0
# 1        1
# 2        3
# 3        4
# 4        5
#       ...
# 618    624
# 619    625
# 620    626
# 621    627
# 622    628
# Name: Unnamed: 0, Length: 623, dtype: int64
