# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("abinet.csv")
df
# Out:
#    name  yederesebet debere kihinete dereja
# 0  sami  tsome digua   rebi          diquna
# 1  sami  tsome digua   rebi          diquna

# %%
#Add columns from list
gender = ["male","female"] #rows
df['Gender'] =gender #this is for creating gender column 
df.head()
# Out:
#    name  yederesebet debere kihinete dereja  Gender
# 0  sami  tsome digua   rebi          diquna    male
# 1  sami  tsome digua   rebi          diquna  female

# %%
# Adding column in the way is used for small amount of data and if you know number of rows
# the data that you are adding must be the same numbers as the numbers of rows.

# %%
df
# Out:
#    name  yederesebet debere kihinete dereja  Gender
# 0  sami  tsome digua   rebi          diquna    male
# 1  sami  tsome digua   rebi          diquna  female

# %%
# Add default values : if you dont know number of rows
df['age'] = [True]*len(df)
df
# Out:
#    name  yederesebet debere kihinete dereja  Gender   age
# 0  sami  tsome digua   rebi          diquna    male  True
# 1  sami  tsome digua   rebi          diquna  female  True

# %%
# you can use string , integer or any type insteadcof the boolean in the above example
df['year'] = ['2007']*len(df)
df
# Out:
#    name  yederesebet debere kihinete dereja  Gender   age  year
# 0  sami  tsome digua   rebi          diquna    male  True  2007
# 1  sami  tsome digua   rebi          diquna  female  True  2007

# %%
# add nan(null value) 
df['next'] = [np.nan]*len(df)
df
# Out:
#    name  yederesebet debere kihinete dereja  Gender   age  year  next
# 0  sami  tsome digua   rebi          diquna    male  True  2007   NaN
# 1  sami  tsome digua   rebi          diquna  female  True  2007   NaN

# %%
# add column using inerst() function - you cdan add with this at any position
df.insert(1,"aquaquam",[True]*len(df), True) # the first values is the index(postion(1)): the next is column name(aquaquam): the next is values(row data) : the last is default value which is True it says allow dupilicate values.

# %%
df
# Out:
#    name  aquaquam  yederesebet debere kihinete dereja  Gender   age  year  \
# 0  sami      True  tsome digua   rebi          diquna    male  True  2007
# 1  sami      True  tsome digua   rebi          diquna  female  True  2007
#
#    next
# 0   NaN
# 1   NaN

# %%
# add columns with the .assign() function - this creates another new dataframe
df2=df.assign(Kidase = [True]*len(df)) # kidase is the column name : the next is value
df2 # is new dataframe created with the kidase column.
# Out:
#    name  aquaquam  yederesebet debere kihinete dereja  Gender   age  year  \
# 0  sami      True  tsome digua   rebi          diquna    male  True  2007
# 1  sami      True  tsome digua   rebi          diquna  female  True  2007
#
#    next  Kidase
# 0   NaN    True
# 1   NaN    True

# %%
df
# Out:
#    name  aquaquam  yederesebet debere kihinete dereja  Gender   age  year  \
# 0  sami      True  tsome digua   rebi          diquna    male  True  2007
# 1  sami      True  tsome digua   rebi          diquna  female  True  2007
#
#    next
# 0   NaN
# 1   NaN
